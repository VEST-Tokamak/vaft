# %% [markdown]
# # Preserved markdown
# This cell must not change.

# %%
print('ordinary stream')
'static result'
# Out:
# static text
# mixed result
# ordinary stream
# ordinary error stream
# Traceback (most recent call last):
# <div>remove me</div>

# %% [raw]
# Raw source must not change.
