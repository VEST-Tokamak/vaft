# %%
from vest.database.raw import *
configuration()

init_pool()

shot = 39915
field = 1
(time, data) = load(shot, field)
# Out:
# Configuration loaded:
# Hostname: 147.46.31.16
# Username: vestuser
# Password: nu31123
# Database: VEST
# Configuration loaded:
# Hostname: 147.46.31.16
# Username: vestuser
# Password: nu31123
# Database: VEST

# %%
plot(45000, 109, xlims=[0.3,0.32])

# %%
plot(45000, [287, 293, 299],xlims=[0.299,0.3], norm_opt=1) # 45, 135, 225 angle
plot(45000,171,xlims=[0.299,0.30], norm_opt=1) # 165 angle

# %%
### Summary

# %%
### DaQ Gain Update

# %%
### PF Current

# %%
### Flux Loop

# %%
### Mangetics Pol Probe

# %%
### Filterscope

# %% [markdown]
# ### Rowgowski Coil

# %% [markdown]
# ### Filterscope
