# %% [markdown]
# Step 1: Verify object creation logic
# Objective: Confirm that the newly implemented IDS wrapper correctly creates an IMAS DBEntry.
# Target: A basic equilibrium or summary IDS.
#
# Step 2: Load and convert legacy data
# Sources:
# 	•	load_omas_h5: Existing VEST ODS data (HDF5 format).
# 	•	VEST-IMAS files generated with Legacy AL4 (.h5 or MDSplus).
#
# Process:
# 	•	Read the legacy data through the IDS_AL4 interface.
# 	•	Map the data to an intermediate OMAS ODS object.
#
# Step 3: Save in the new IMAS (AL5) format
# Objective: Store the data in a format compatible with the latest open-source IMAS stack.
# Function: Calling save_omas_imas(ods, ..., new=True) automatically creates an AL5 DBEntry and writes the data.

# %%
import imas
from omas import *
